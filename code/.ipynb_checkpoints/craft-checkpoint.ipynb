# %%
import torch
from torch import nn
import torch.nn as nn
import torch.nn.functional as F
from torch.utils.data import DataLoader
import torch.nn.utils.prune as prune

import torchvision
from torchvision import datasets
from torchvision import transforms
from torchmetrics import Accuracy

import torch.optim as optim

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

import random
import copy
import gc
import math

import warnings
warnings.filterwarnings('ignore')

from pathlib import Path
from resnet_18 import *

import cv2
import timm
from timm.data import resolve_data_config
from timm.data.transforms_factory import create_transform
from math import ceil

from craft.craft_torch import Craft, torch_to_numpy

import matplotlib
import colorsys

# %%
print(torch.cuda.is_available())
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
# Out:
# True

# %%
model_architecture = 'resnet18' 
checkpoint_path = 'saves/resnet/imagenette/0_model_lt.pth.tar'

model = timm.create_model(model_architecture,pretrained=False,num_classes=10 )
loaded_object = torch.load(checkpoint_path, map_location=device, weights_only=False)
state_dict = loaded_object.state_dict()
model.load_state_dict(state_dict)
model = model.eval().to(device)

# %%
# processing
config = resolve_data_config({}, model=model)
transform = create_transform(**config)
to_pil = transforms.ToPILImage()

# cut the model in two
g = nn.Sequential(
    model.conv1,
    model.bn1,
    model.relu,
    model.maxpool,
    model.layer1,
    model.layer2,
    model.layer3,
    model.layer4
)
h = nn.Sequential(
    model.global_pool,
    nn.Flatten(1), # Flattens the output of the pool layer for the fc layer
    model.fc
)

# %%
springer_class = 2 # imagenet class for springer

# loading some images of rabbits !
images = np.load('collected_images/springer.npz')['images']
images_preprocessed = torch.from_numpy(images)

images_preprocessed.shape
# Out:
# torch.Size([500, 3, 224, 224])

# %%
craft = Craft(input_to_latent = g,
              latent_to_logit = h,
              number_of_concepts = 10,
              patch_size = 32,
              batch_size = 64,
              device = device)

crops, crops_u, w = craft.fit(images_preprocessed)
crops = np.moveaxis(torch_to_numpy(crops), 1, -1)

crops.shape, crops_u.shape, w.shape
# Out:
# ((32000, 32, 32, 3), (32000, 10), (10, 64))

# %%
importances = craft.estimate_importance(images_preprocessed, class_id=springer_class)
images_u = craft.transform(images_preprocessed)

images_u.shape
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 importances = craft.estimate_importance(images_preprocessed, class_id=springer_class)
#       2 images_u = craft.transform(images_preprocessed)
#       4 images_u.shape
#
# File ~\anaconda3\Lib\site-packages\craft\craft_torch.py:288, in Craft.estimate_importance(self, inputs, class_id, nb_design)
#     285 a_perturbated = np.reshape(a_perturbated, (len(masks), U.shape[1], U.shape[2], -1))
#     286 a_perturbated = np.moveaxis(a_perturbated, -1, 1)
# --> 288 y_pred = _batch_inference(self.latent_to_logit, a_perturbated, self.batch_size,
#     289                           device=self.device)
#     290 y_pred = y_pred[:, class_id]
#     292 stis = estimator(torch_to_numpy(masks),
#     293                  torch_to_numpy(y_pred),
#     294                  nb_design)
#
# File ~\anaconda3\Lib\site-packages\craft\craft_torch.py:40, in _batch_inference(model, dataset, batch_size, resize, device)
#      37     if resize:
#      38       x = torch.nn.functional.interpolate(x, size=resize, mode='bilinear', align_corners=False)
# ---> 40     results.append(model(x).cpu())
#      42 results = torch.cat(results)
#      43 return results
#
# Cell In[9], line 8, in <lambda>(x)
#       6 # cut the model in two
#       7 g = nn.Sequential(*(list(model.children())[:4])) # input to penultimate layer
# ----> 8 h = lambda x: model.head.fc(torch.mean(x, (2, 3)))
#
# File ~\anaconda3\Lib\site-packages\torch\nn\modules\module.py:1940, in Module.__getattr__(self, name)
#    1938     if name in modules:
#    1939         return modules[name]
# -> 1940 raise AttributeError(
#    1941     f"'{type(self).__name__}' object has no attribute '{name}'"
#    1942 )
#
# AttributeError: 'ResNet' object has no attribute 'head'
