# %%
import os
import sys
from tqdm import tqdm
from ranger import Ranger
from tensorboardX import SummaryWriter

import torch
from torch import nn
import torch.nn as nn
import torch.nn.functional as F
from torch.utils.data import DataLoader
import torch.nn.utils.prune as prune
import torch.nn.init as init

import torchvision
from torchvision import datasets
from torchvision import transforms
from torchvision.transforms import Normalize
from torchmetrics import Accuracy
import torchvision.utils as vutils

import torch.optim as optim
from cleverhans.torch.attacks.projected_gradient_descent import (projected_gradient_descent)

import quantus
import captum
from captum.attr import Saliency, IntegratedGradients, NoiseTunnel

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

import pickle
import random
import copy
import gc

import warnings
warnings.filterwarnings('ignore')

# %%
# %run utils.ipynb

# %%
writer = SummaryWriter()

# %%
# Plotting Style
sns.set_style('darkgrid')

# %%
print(torch.cuda.is_available())
# Out:
# True

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %%
batch_size = 64
transform=transforms.Compose([transforms.ToTensor(),transforms.Normalize((0.1307,), (0.3081,))])
traindataset = datasets.FashionMNIST('../data', train=True, download=True,transform=transform)
testdataset = datasets.FashionMNIST('../data', train=False, transform=transform)

# %%
train_dataloader = torch.utils.data.DataLoader(traindataset, batch_size=batch_size, shuffle=True, num_workers=0,drop_last=False)
test_dataloader = torch.utils.data.DataLoader(testdataset, batch_size=batch_size, shuffle=False, num_workers=0,drop_last=True)

# %%
# %run models.ipynb

# %%
model = resnet18_features(pretrained=False, filter='None', filter_layer=0).to(device)
learning_rate = 1e-4
start_iter = 0
end_iter = 30
print_freq = 1
valid_freq = 1
prune_type = 'lt'
prune_percent = 10
prune_iterations = 35

# %%
model.apply(weight_init)
# Out:
# ResNet_features(
#   (conv1): Conv2d(1, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#   (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (relu): ReLU(inplace=True)
#   (maxpool): Identity()
#   (global_pool): AdaptiveAvgPool2d(output_size=(1, 1))
#   (layer1): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (layer2): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(64, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (downsample): Sequential(
#         (0): Conv2d(64, 128, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (layer3): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(128, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (downsample): Sequential(
#         (0): Conv2d(128, 256, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (layer4): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(256, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (downsample): Sequential(
#         (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (fc): Linear(in_features=512, out_features=10, bias=True)
# )

# %%
initial_state_dict = copy.deepcopy(model.state_dict())
checkdir(f"{os.getcwd()}/saves/resnet/fmnist/")
torch.save(model, f"{os.getcwd()}/saves/resnet/fmnist/initial_state_dict_lt.pth.tar")

# %%
make_mask(model)

# %%
# optimizer = torch.optim.Adam(model.parameters(), weight_decay=1e-4)
# criterion = nn.CrossEntropyLoss() 
criterion = nn.CrossEntropyLoss(reduction="mean").cuda()
optimizer = torch.optim.Adam(model.parameters(), weight_decay=1e-4)

# %%
for name, param in model.named_parameters():
        print(name, param.size())
# Out:
# conv1.weight torch.Size([64, 1, 3, 3])
# bn1.weight torch.Size([64])
# bn1.bias torch.Size([64])
# layer1.0.conv1.weight torch.Size([64, 64, 3, 3])
# layer1.0.bn1.weight torch.Size([64])
# layer1.0.bn1.bias torch.Size([64])
# layer1.0.conv2.weight torch.Size([64, 64, 3, 3])
# layer1.0.bn2.weight torch.Size([64])
# layer1.0.bn2.bias torch.Size([64])
# layer1.1.conv1.weight torch.Size([64, 64, 3, 3])
# layer1.1.bn1.weight torch.Size([64])
# layer1.1.bn1.bias torch.Size([64])
# layer1.1.conv2.weight torch.Size([64, 64, 3, 3])
# layer1.1.bn2.weight torch.Size([64])
# layer1.1.bn2.bias torch.Size([64])
# layer2.0.conv1.weight torch.Size([128, 64, 3, 3])
# layer2.0.bn1.weight torch.Size([128])
# layer2.0.bn1.bias torch.Size([128])
# layer2.0.conv2.weight torch.Size([128, 128, 3, 3])
# layer2.0.bn2.weight torch.Size([128])
# layer2.0.bn2.bias torch.Size([128])
# layer2.0.downsample.0.weight torch.Size([128, 64, 1, 1])
# layer2.0.downsample.1.weight torch.Size([128])
# layer2.0.downsample.1.bias torch.Size([128])
# layer2.1.conv1.weight torch.Size([128, 128, 3, 3])
# layer2.1.bn1.weight torch.Size([128])
# layer2.1.bn1.bias torch.Size([128])
# layer2.1.conv2.weight torch.Size([128, 128, 3, 3])
# layer2.1.bn2.weight torch.Size([128])
# layer2.1.bn2.bias torch.Size([128])
# layer3.0.conv1.weight torch.Size([256, 128, 3, 3])
# layer3.0.bn1.weight torch.Size([256])
# layer3.0.bn1.bias torch.Size([256])
# layer3.0.conv2.weight torch.Size([256, 256, 3, 3])
# layer3.0.bn2.weight torch.Size([256])
# layer3.0.bn2.bias torch.Size([256])
# layer3.0.downsample.0.weight torch.Size([256, 128, 1, 1])
# layer3.0.downsample.1.weight torch.Size([256])
# layer3.0.downsample.1.bias torch.Size([256])
# layer3.1.conv1.weight torch.Size([256, 256, 3, 3])
# layer3.1.bn1.weight torch.Size([256])
# layer3.1.bn1.bias torch.Size([256])
# layer3.1.conv2.weight torch.Size([256, 256, 3, 3])
# layer3.1.bn2.weight torch.Size([256])
# layer3.1.bn2.bias torch.Size([256])
# layer4.0.conv1.weight torch.Size([512, 256, 3, 3])
# layer4.0.bn1.weight torch.Size([512])
# layer4.0.bn1.bias torch.Size([512])
# layer4.0.conv2.weight torch.Size([512, 512, 3, 3])
# layer4.0.bn2.weight torch.Size([512])
# layer4.0.bn2.bias torch.Size([512])
# layer4.0.downsample.0.weight torch.Size([512, 256, 1, 1])
# layer4.0.downsample.1.weight torch.Size([512])
# layer4.0.downsample.1.bias torch.Size([512])
# layer4.1.conv1.weight torch.Size([512, 512, 3, 3])
# layer4.1.bn1.weight torch.Size([512])
# layer4.1.bn1.bias torch.Size([512])
# layer4.1.conv2.weight torch.Size([512, 512, 3, 3])
# layer4.1.bn2.weight torch.Size([512])
# layer4.1.bn2.bias torch.Size([512])
# fc.weight torch.Size([10, 512])
# fc.bias torch.Size([10])

# %%
# Pruning
# NOTE First Pruning Iteration is of No Compression
bestacc = 0.0
best_accuracy = 0
ITERATION = prune_iterations
comp = np.zeros(ITERATION,float)
bestacc = np.zeros(ITERATION,float)
step = 0
all_loss = np.zeros(end_iter,float)
all_accuracy = np.zeros(end_iter,float)
ITE=1

# %%
for _ite in range(start_iter, ITERATION):
    if not _ite == 0:
        prune_by_percentile(prune_percent, resample=False, reinit=False)
        original_initialization(mask, initial_state_dict)
        optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate, weight_decay=1e-4)
        
    print(f"\n--- Pruning Level [{ITE}:{_ite}/{ITERATION}]: ---")

    # Print the table of Nonzeros in each layer
    comp1 = print_nonzeros(model)
    comp[_ite] = comp1
    pbar = tqdm(range(end_iter))

    for iter_ in pbar:

        # Frequency for Testing
        if iter_ % valid_freq == 0:
            accuracy = test(model, test_dataloader, criterion)

            # Save Weights
            if accuracy > best_accuracy:
                best_accuracy = accuracy
                checkdir(f"{os.getcwd()}/saves/resnet/fmnist/")
                torch.save(model,f"{os.getcwd()}/saves/resnet/fmnist/{_ite}_model_lt.pth.tar")

        # Training
        loss = train(model, train_dataloader, optimizer, criterion)
        all_loss[iter_] = loss
        all_accuracy[iter_] = accuracy
        
        # Frequency for Printing Accuracy and Loss
        if iter_ % print_freq == 0:
            pbar.set_description(
                f'Train Epoch: {iter_}/{end_iter} Loss: {loss:.6f} Accuracy: {accuracy:.2f}% Best Accuracy: {best_accuracy:.2f}%')       

    writer.add_scalar('Accuracy/test', best_accuracy, comp1)
    bestacc[_ite]=best_accuracy

    # Plotting Loss (Training), Accuracy (Testing), Iteration Curve
    #NOTE Loss is computed for every iteration while Accuracy is computed only for every {args.valid_freq} iterations. Therefore Accuracy saved is constant during the uncomputed iterations.
    #NOTE Normalized the accuracy to [0,100] for ease of plotting.
    plt.plot(np.arange(1,(end_iter)+1), 100*(all_loss - np.min(all_loss))/np.ptp(all_loss).astype(float), c="blue", label="Loss") 
    plt.plot(np.arange(1,(end_iter)+1), all_accuracy, c="red", label="Accuracy") 
    plt.title(f"Loss Vs Accuracy Vs Iterations (fmnist,resnet)") 
    plt.xlabel("Iterations") 
    plt.ylabel("Loss and Accuracy") 
    plt.legend() 
    plt.grid(color="gray") 
    checkdir(f"{os.getcwd()}/plots/lt/resnet/fmnist/")
    plt.savefig(f"{os.getcwd()}/plots/lt/resnet/fmnist/lt_LossVsAccuracy_{comp1}.png", dpi=1200) 
    plt.close()

    # Dump Plot values
    checkdir(f"{os.getcwd()}/dumps/lt/resnet/fmnist/")
    all_loss.dump(f"{os.getcwd()}/dumps/lt/resnet/fmnist/lt_all_loss_{comp1}.dat")
    all_accuracy.dump(f"{os.getcwd()}/dumps/lt/resnet/fmnist/lt_all_accuracy_{comp1}.dat")
    
    # Dumping mask
    checkdir(f"{os.getcwd()}/dumps/lt/resnet/fmnist/")
    with open(f"{os.getcwd()}/dumps/lt/resnet/fmnist/lt_mask_{comp1}.pkl", 'wb') as fp:
        pickle.dump(mask, fp)
    
    # Making variables into 0
    best_accuracy = 0
    all_loss = np.zeros(end_iter,float)
    all_accuracy = np.zeros(end_iter,float)

# Dumping Values for Plotting
checkdir(f"{os.getcwd()}/dumps/lt/resnet/fmnist/")
comp.dump(f"{os.getcwd()}/dumps/lt/resnet/fmnist/lt_compression.dat")
bestacc.dump(f"{os.getcwd()}/dumps/lt/resnet/fmnist/lt_bestaccuracy.dat")

# Plotting
a = np.arange(prune_iterations)
plt.plot(a, bestacc, c="blue", label="Winning tickets") 
plt.title(f"Test Accuracy vs Unpruned Weights Percentage (fmnist,resnet)") 
plt.xlabel("Unpruned Weights Percentage") 
plt.ylabel("test accuracy") 
plt.xticks(a, comp, rotation ="vertical") 
plt.ylim(0,100)
plt.legend() 
plt.grid(color="gray") 
checkdir(f"{os.getcwd()}/plots/lt/resnet/fmnist/")
plt.savefig(f"{os.getcwd()}/plots/lt/resnet/fmnist/lt_AccuracyVsWeights.png", dpi=1200) 
plt.close()
# Out:
# --- Pruning Level [1:0/35]: ---
# conv1.weight         | nonzeros =     576 /     576 (100.00%) | total_pruned =       0 | shape = (64, 1, 3, 3)
# bn1.weight           | nonzeros =      64 /      64 (100.00%) | total_pruned =       0 | shape = (64,)
# bn1.bias             | nonzeros =       0 /      64 (  0.00%) | total_pruned =      64 | shape = (64,)
# layer1.0.conv1.weight | nonzeros =   36864 /   36864 (100.00%) | total_pruned =       0 | shape = (64, 64, 3, 3)
# layer1.0.bn1.weight  | nonzeros =      64 /      64 (100.00%) | total_pruned =       0 | shape = (64,)
# layer1.0.bn1.bias    | nonzeros =       0 /      64 (  0.00%) | total_pruned =      64 | shape = (64,)
# layer1.0.conv2.weight | nonzeros =   36864 /   36864 (100.00%) | total_pruned =       0 | shape = (64, 64, 3, 3)
# layer1.0.bn2.weight  | nonzeros =      64 /      64 (100.00%) | total_pruned =       0 | shape = (64,)
# layer1.0.bn2.bias    | nonzeros =       0 /      64 (  0.00%) | total_pruned =      64 | shape = (64,)
# layer1.1.conv1.weight | nonzeros =   36864 /   36864 (100.00%) | total_pruned =       0 | shape = (64, 64, 3, 3)
# layer1.1.bn1.weight  | nonzeros =      64 /      64 (100.00%) | total_pruned =       0 | shape = (64,)
# layer1.1.bn1.bias    | nonzeros =       0 /      64 (  0.00%) | total_pruned =      64 | shape = (64,)
# layer1.1.conv2.weight | nonzeros =   36864 /   36864 (100.00%) | total_pruned =       0 | shape = (64, 64, 3, 3)
# layer1.1.bn2.weight  | nonzeros =      64 /      64 (100.00%) | total_pruned =       0 | shape = (64,)
# layer1.1.bn2.bias    | nonzeros =       0 /      64 (  0.00%) | total_pruned =      64 | shape = (64,)
# layer2.0.conv1.weight | nonzeros =   73728 /   73728 (100.00%) | total_pruned =       0 | shape = (128, 64, 3, 3)
# layer2.0.bn1.weight  | nonzeros =     128 /     128 (100.00%) | total_pruned =       0 | shape = (128,)
# layer2.0.bn1.bias    | nonzeros =       0 /     128 (  0.00%) | total_pruned =     128 | shape = (128,)
# layer2.0.conv2.weight | nonzeros =  147456 /  147456 (100.00%) | total_pruned =       0 | shape = (128, 128, 3, 3)
# layer2.0.bn2.weight  | nonzeros =     128 /     128 (100.00%) | total_pruned =       0 | shape = (128,)
# layer2.0.bn2.bias    | nonzeros =       0 /     128 (  0.00%) | total_pruned =     128 | shape = (128,)
# layer2.0.downsample.0.weight | nonzeros =    8192 /    8192 (100.00%) | total_pruned =       0 | shape = (128, 64, 1, 1)
# layer2.0.downsample.1.weight | nonzeros =     128 /     128 (100.00%) | total_pruned =       0 | shape = (128,)
# layer2.0.downsample.1.bias | nonzeros =       0 /     128 (  0.00%) | total_pruned =     128 | shape = (128,)
# layer2.1.conv1.weight | nonzeros =  147456 /  147456 (100.00%) | total_pruned =       0 | shape = (128, 128, 3, 3)
# layer2.1.bn1.weight  | nonzeros =     128 /     128 (100.00%) | total_pruned =       0 | shape = (128,)
# layer2.1.bn1.bias    | nonzeros =       0 /     128 (  0.00%) | total_pruned =     128 | shape = (128,)
# layer2.1.conv2.weight | nonzeros =  147456 /  147456 (100.00%) | total_pruned =       0 | shape = (128, 128, 3, 3)
# layer2.1.bn2.weight  | nonzeros =     128 /     128 (100.00%) | total_pruned =       0 | shape = (128,)
# layer2.1.bn2.bias    | nonzeros =       0 /     128 (  0.00%) | total_pruned =     128 | shape = (128,)
# layer3.0.conv1.weight | nonzeros =  294912 /  294912 (100.00%) | total_pruned =       0 | shape = (256, 128, 3, 3)
# layer3.0.bn1.weight  | nonzeros =     256 /     256 (100.00%) | total_pruned =       0 | shape = (256,)
# layer3.0.bn1.bias    | nonzeros =       0 /     256 (  0.00%) | total_pruned =     256 | shape = (256,)
# layer3.0.conv2.weight | nonzeros =  589824 /  589824 (100.00%) | total_pruned =       0 | shape = (256, 256, 3, 3)
# layer3.0.bn2.weight  | nonzeros =     256 /     256 (100.00%) | total_pruned =       0 | shape = (256,)
# layer3.0.bn2.bias    | nonzeros =       0 /     256 (  0.00%) | total_pruned =     256 | shape = (256,)
# layer3.0.downsample.0.weight | nonzeros =   32768 /   32768 (100.00%) | total_pruned =       0 | shape = (256, 128, 1, 1)
# layer3.0.downsample.1.weight | nonzeros =     256 /     256 (100.00%) | total_pruned =       0 | shape = (256,)
# layer3.0.downsample.1.bias | nonzeros =       0 /     256 (  0.00%) | total_pruned =     256 | shape = (256,)
# layer3.1.conv1.weight | nonzeros =  589824 /  589824 (100.00%) | total_pruned =       0 | shape = (256, 256, 3, 3)
# layer3.1.bn1.weight  | nonzeros =     256 /     256 (100.00%) | total_pruned =       0 | shape = (256,)
# layer3.1.bn1.bias    | nonzeros =       0 /     256 (  0.00%) | total_pruned =     256 | shape = (256,)
# layer3.1.conv2.weight | nonzeros =  589824 /  589824 (100.00%) | total_pruned =       0 | shape = (256, 256, 3, 3)
# layer3.1.bn2.weight  | nonzeros =     256 /     256 (100.00%) | total_pruned =       0 | shape = (256,)
# layer3.1.bn2.bias    | nonzeros =       0 /     256 (  0.00%) | total_pruned =     256 | shape = (256,)
# layer4.0.conv1.weight | nonzeros = 1179648 / 1179648 (100.00%) | total_pruned =       0 | shape = (512, 256, 3, 3)
# layer4.0.bn1.weight  | nonzeros =     512 /     512 (100.00%) | total_pruned =       0 | shape = (512,)
# layer4.0.bn1.bias    | nonzeros =       0 /     512 (  0.00%) | total_pruned =     512 | shape = (512,)
# layer4.0.conv2.weight | nonzeros = 2359296 / 2359296 (100.00%) | total_pruned =       0 | shape = (512, 512, 3, 3)
# layer4.0.bn2.weight  | nonzeros =     512 /     512 (100.00%) | total_pruned =       0 | shape = (512,)
# layer4.0.bn2.bias    | nonzeros =       0 /     512 (  0.00%) | total_pruned =     512 | shape = (512,)
# layer4.0.downsample.0.weight | nonzeros =  131072 /  131072 (100.00%) | total_pruned =       0 | shape = (512, 256, 1, 1)
# layer4.0.downsample.1.weight | nonzeros =     512 /     512 (100.00%) | total_pruned =       0 | shape = (512,)
# layer4.0.downsample.1.bias | nonzeros =       0 /     512 (  0.00%) | total_pruned =     512 | shape = (512,)
# layer4.1.conv1.weight | nonzeros = 2359296 / 2359296 (100.00%) | total_pruned =       0 | shape = (512, 512, 3, 3)
# layer4.1.bn1.weight  | nonzeros =     512 /     512 (100.00%) | total_pruned =       0 | shape = (512,)
# layer4.1.bn1.bias    | nonzeros =       0 /     512 (  0.00%) | total_pruned =     512 | shape = (512,)
# layer4.1.conv2.weight | nonzeros = 2359296 / 2359296 (100.00%) | total_pruned =       0 | shape = (512, 512, 3, 3)
# layer4.1.bn2.weight  | nonzeros =     512 /     512 (100.00%) | total_pruned =       0 | shape = (512,)
# layer4.1.bn2.bias    | nonzeros =       0 /     512 (  0.00%) | total_pruned =     512 | shape = (512,)
# fc.weight            | nonzeros =    5120 /    5120 (100.00%) | total_pruned =       0 | shape = (10, 512)
# fc.bias              | nonzeros =      10 /      10 (100.00%) | total_pruned =       0 | shape = (10,)
# alive: 11168010, pruned : 4800, total: 11172810, Compression rate :       1.00x  (  0.04% pruned)
# Train Epoch: 29/30 Loss: 0.091193 Accuracy: 64.16% Best Accuracy: 89.09%: 100%|████████| 30/30 [35:53<00:00, 71.79s/it]
# --- Pruning Level [1:1/35]: ---
# conv1.weight         | nonzeros =     519 /     576 ( 90.10%) | total_pruned =      57 | shape = (64, 1, 3, 3)
# bn1.weight           | nonzeros =      57 /      64 ( 89.06%) | total_pruned =       7 | shape = (64,)
# bn1.bias             | nonzeros =       0 /      64 (  0.00%) | total_pruned =      64 | shape = (64,)
# layer1.0.conv1.weight | nonzeros =   33239 /   36864 ( 90.17%) | total_pruned =    3625 | shape = (64, 64, 3, 3)
# layer1.0.bn1.weight  | nonzeros =      57 /      64 ( 89.06%) | total_pruned =       7 | shape = (64,)
# layer1.0.bn1.bias    | nonzeros =       0 /      64 (  0.00%) | total_pruned =      64 | shape = (64,)
# layer1.0.conv2.weight | nonzeros =   33197 /   36864 ( 90.05%) | total_pruned =    3667 | shape = (64, 64, 3, 3)
# layer1.0.bn2.weight  | nonzeros =      57 /      64 ( 89.06%) | total_pruned =       7 | shape = (64,)
# layer1.0.bn2.bias    | nonzeros =       0 /      64 (  0.00%) | total_pruned =      64 | shape = (64,)
# layer1.1.conv1.weight | nonzeros =   33269 /   36864 ( 90.25%) | total_pruned =    3595 | shape = (64, 64, 3, 3)
# layer1.1.bn1.weight  | nonzeros =      57 /      64 ( 89.06%) | total_pruned =       7 | shape = (64,)
# layer1.1.bn1.bias    | nonzeros =       0 /      64 (  0.00%) | total_pruned =      64 | shape = (64,)
# layer1.1.conv2.weight | nonzeros =   33220 /   36864 ( 90.12%) | total_pruned =    3644 | shape = (64, 64, 3, 3)
# layer1.1.bn2.weight  | nonzeros =      57 /      64 ( 89.06%) | total_pruned =       7 | shape = (64,)
# layer1.1.bn2.bias    | nonzeros =       0 /      64 (  0.00%) | total_pruned =      64 | shape = (64,)
# layer2.0.conv1.weight | nonzeros =   66398 /   73728 ( 90.06%) | total_pruned =    7330 | shape = (128, 64, 3, 3)
# layer2.0.bn1.weight  | nonzeros =     115 /     128 ( 89.84%) | total_pruned =      13 | shape = (128,)
# layer2.0.bn1.bias    | nonzeros =       0 /     128 (  0.00%) | total_pruned =     128 | shape = (128,)
# layer2.0.conv2.weight | nonzeros =  132855 /  147456 ( 90.10%) | total_pruned =   14601 | shape = (128, 128, 3, 3)
# layer2.0.bn2.weight  | nonzeros =     115 /     128 ( 89.84%) | total_pruned =      13 | shape = (128,)
# layer2.0.bn2.bias    | nonzeros =       0 /     128 (  0.00%) | total_pruned =     128 | shape = (128,)
# layer2.0.downsample.0.weight | nonzeros =    7381 /    8192 ( 90.10%) | total_pruned =     811 | shape = (128, 64, 1, 1)
# layer2.0.downsample.1.weight | nonzeros =     115 /     128 ( 89.84%) | total_pruned =      13 | shape = (128,)
# layer2.0.downsample.1.bias | nonzeros =       0 /     128 (  0.00%) | total_pruned =     128 | shape = (128,)
# layer2.1.conv1.weight | nonzeros =  132891 /  147456 ( 90.12%) | total_pruned =   14565 | shape = (128, 128, 3, 3)
# layer2.1.bn1.weight  | nonzeros =     115 /     128 ( 89.84%) | total_pruned =      13 | shape = (128,)
# layer2.1.bn1.bias    | nonzeros =       0 /     128 (  0.00%) | total_pruned =     128 | shape = (128,)
# layer2.1.conv2.weight | nonzeros =  132945 /  147456 ( 90.16%) | total_pruned =   14511 | shape = (128, 128, 3, 3)
# layer2.1.bn2.weight  | nonzeros =     115 /     128 ( 89.84%) | total_pruned =      13 | shape = (128,)
# layer2.1.bn2.bias    | nonzeros =       0 /     128 (  0.00%) | total_pruned =     128 | shape = (128,)
# layer3.0.conv1.weight | nonzeros =  265937 /  294912 ( 90.18%) | total_pruned =   28975 | shape = (256, 128, 3, 3)
# layer3.0.bn1.weight  | nonzeros =     230 /     256 ( 89.84%) | total_pruned =      26 | shape = (256,)
# layer3.0.bn1.bias    | nonzeros =       0 /     256 (  0.00%) | total_pruned =     256 | shape = (256,)
# layer3.0.conv2.weight | nonzeros =  531490 /  589824 ( 90.11%) | total_pruned =   58334 | shape = (256, 256, 3, 3)
# layer3.0.bn2.weight  | nonzeros =     230 /     256 ( 89.84%) | total_pruned =      26 | shape = (256,)
# layer3.0.bn2.bias    | nonzeros =       0 /     256 (  0.00%) | total_pruned =     256 | shape = (256,)
# layer3.0.downsample.0.weight | nonzeros =   29521 /   32768 ( 90.09%) | total_pruned =    3247 | shape = (256, 128, 1, 1)
# layer3.0.downsample.1.weight | nonzeros =     230 /     256 ( 89.84%) | total_pruned =      26 | shape = (256,)
# layer3.0.downsample.1.bias | nonzeros =       0 /     256 (  0.00%) | total_pruned =     256 | shape = (256,)
# layer3.1.conv1.weight | nonzeros =  531145 /  589824 ( 90.05%) | total_pruned =   58679 | shape = (256, 256, 3, 3)
# layer3.1.bn1.weight  | nonzeros =     231 /     256 ( 90.23%) | total_pruned =      25 | shape = (256,)
# layer3.1.bn1.bias    | nonzeros =       0 /     256 (  0.00%) | total_pruned =     256 | shape = (256,)
# layer3.1.conv2.weight | nonzeros =  531230 /  589824 ( 90.07%) | total_pruned =   58594 | shape = (256, 256, 3, 3)
# layer3.1.bn2.weight  | nonzeros =     230 /     256 ( 89.84%) | total_pruned =      26 | shape = (256,)
# layer3.1.bn2.bias    | nonzeros =       0 /     256 (  0.00%) | total_pruned =     256 | shape = (256,)
# layer4.0.conv1.weight | nonzeros = 1063816 / 1179648 ( 90.18%) | total_pruned =  115832 | shape = (512, 256, 3, 3)
# layer4.0.bn1.weight  | nonzeros =     461 /     512 ( 90.04%) | total_pruned =      51 | shape = (512,)
# layer4.0.bn1.bias    | nonzeros =       0 /     512 (  0.00%) | total_pruned =     512 | shape = (512,)
# layer4.0.conv2.weight | nonzeros = 2127720 / 2359296 ( 90.18%) | total_pruned =  231576 | shape = (512, 512, 3, 3)
# layer4.0.bn2.weight  | nonzeros =     460 /     512 ( 89.84%) | total_pruned =      52 | shape = (512,)
# layer4.0.bn2.bias    | nonzeros =       0 /     512 (  0.00%) | total_pruned =     512 | shape = (512,)
# layer4.0.downsample.0.weight | nonzeros =  118268 /  131072 ( 90.23%) | total_pruned =   12804 | shape = (512, 256, 1, 1)
# layer4.0.downsample.1.weight | nonzeros =     460 /     512 ( 89.84%) | total_pruned =      52 | shape = (512,)
# layer4.0.downsample.1.bias | nonzeros =       0 /     512 (  0.00%) | total_pruned =     512 | shape = (512,)
# layer4.1.conv1.weight | nonzeros = 2123625 / 2359296 ( 90.01%) | total_pruned =  235671 | shape = (512, 512, 3, 3)
# layer4.1.bn1.weight  | nonzeros =     462 /     512 ( 90.23%) | total_pruned =      50 | shape = (512,)
# layer4.1.bn1.bias    | nonzeros =       0 /     512 (  0.00%) | total_pruned =     512 | shape = (512,)
# layer4.1.conv2.weight | nonzeros = 2126683 / 2359296 ( 90.14%) | total_pruned =  232613 | shape = (512, 512, 3, 3)
# layer4.1.bn2.weight  | nonzeros =     460 /     512 ( 89.84%) | total_pruned =      52 | shape = (512,)
# layer4.1.bn2.bias    | nonzeros =       0 /     512 (  0.00%) | total_pruned =     512 | shape = (512,)
# fc.weight            | nonzeros =    4610 /    5120 ( 90.04%) | total_pruned =     510 | shape = (10, 512)
# fc.bias              | nonzeros =      10 /      10 (100.00%) | total_pruned =       0 | shape = (10,)
# alive: 10064283, pruned : 1108527, total: 11172810, Compression rate :       1.11x  (  9.92% pruned)
# Train Epoch: 29/30 Loss: 0.571485 Accuracy: 82.13% Best Accuracy: 84.49%: 100%|████████| 30/30 [35:49<00:00, 71.65s/it]
# --- Pruning Level [1:2/35]: ---
# conv1.weight         | nonzeros =     468 /     576 ( 81.25%) | total_pruned =     108 | shape = (64, 1, 3, 3)
# bn1.weight           | nonzeros =      51 /      64 ( 79.69%) | total_pruned =      13 | shape = (64,)
# bn1.bias             | nonzeros =      57 /      64 ( 89.06%) | total_pruned =       7 | shape = (64,)
# layer1.0.conv1.weight | nonzeros =   29966 /   36864 ( 81.29%) | total_pruned =    6898 | shape = (64, 64, 3, 3)
# layer1.0.bn1.weight  | nonzeros =      51 /      64 ( 79.69%) | total_pruned =      13 | shape = (64,)
# layer1.0.bn1.bias    | nonzeros =      57 /      64 ( 89.06%) | total_pruned =       7 | shape = (64,)
# layer1.0.conv2.weight | nonzeros =   29910 /   36864 ( 81.14%) | total_pruned =    6954 | shape = (64, 64, 3, 3)
# layer1.0.bn2.weight  | nonzeros =      51 /      64 ( 79.69%) | total_pruned =      13 | shape = (64,)
# layer1.0.bn2.bias    | nonzeros =      62 /      64 ( 96.88%) | total_pruned =       2 | shape = (64,)
# layer1.1.conv1.weight | nonzeros =   29974 /   36864 ( 81.31%) | total_pruned =    6890 | shape = (64, 64, 3, 3)
# layer1.1.bn1.weight  | nonzeros =      51 /      64 ( 79.69%) | total_pruned =      13 | shape = (64,)
# layer1.1.bn1.bias    | nonzeros =      57 /      64 ( 89.06%) | total_pruned =       7 | shape = (64,)
# layer1.1.conv2.weight | nonzeros =   29907 /   36864 ( 81.13%) | total_pruned =    6957 | shape = (64, 64, 3, 3)
# layer1.1.bn2.weight  | nonzeros =      51 /      64 ( 79.69%) | total_pruned =      13 | shape = (64,)
# layer1.1.bn2.bias    | nonzeros =      64 /      64 (100.00%) | total_pruned =       0 | shape = (64,)
# layer2.0.conv1.weight | nonzeros =   59817 /   73728 ( 81.13%) | total_pruned =   13911 | shape = (128, 64, 3, 3)
# layer2.0.bn1.weight  | nonzeros =     103 /     128 ( 80.47%) | total_pruned =      25 | shape = (128,)
# layer2.0.bn1.bias    | nonzeros =     115 /     128 ( 89.84%) | total_pruned =      13 | shape = (128,)
# layer2.0.conv2.weight | nonzeros =  119683 /  147456 ( 81.17%) | total_pruned =   27773 | shape = (128, 128, 3, 3)
# layer2.0.bn2.weight  | nonzeros =     103 /     128 ( 80.47%) | total_pruned =      25 | shape = (128,)
# layer2.0.bn2.bias    | nonzeros =     122 /     128 ( 95.31%) | total_pruned =       6 | shape = (128,)
# layer2.0.downsample.0.weight | nonzeros =    6647 /    8192 ( 81.14%) | total_pruned =    1545 | shape = (128, 64, 1, 1)
# layer2.0.downsample.1.weight | nonzeros =     103 /     128 ( 80.47%) | total_pruned =      25 | shape = (128,)
# layer2.0.downsample.1.bias | nonzeros =     122 /     128 ( 95.31%) | total_pruned =       6 | shape = (128,)
# layer2.1.conv1.weight | nonzeros =  119773 /  147456 ( 81.23%) | total_pruned =   27683 | shape = (128, 128, 3, 3)
# layer2.1.bn1.weight  | nonzeros =     103 /     128 ( 80.47%) | total_pruned =      25 | shape = (128,)
# layer2.1.bn1.bias    | nonzeros =     115 /     128 ( 89.84%) | total_pruned =      13 | shape = (128,)
# layer2.1.conv2.weight | nonzeros =  119725 /  147456 ( 81.19%) | total_pruned =   27731 | shape = (128, 128, 3, 3)
# layer2.1.bn2.weight  | nonzeros =     103 /     128 ( 80.47%) | total_pruned =      25 | shape = (128,)
# layer2.1.bn2.bias    | nonzeros =     124 /     128 ( 96.88%) | total_pruned =       4 | shape = (128,)
# layer3.0.conv1.weight | nonzeros =  239428 /  294912 ( 81.19%) | total_pruned =   55484 | shape = (256, 128, 3, 3)
# layer3.0.bn1.weight  | nonzeros =     207 /     256 ( 80.86%) | total_pruned =      49 | shape = (256,)
# layer3.0.bn1.bias    | nonzeros =     230 /     256 ( 89.84%) | total_pruned =      26 | shape = (256,)
# layer3.0.conv2.weight | nonzeros =  478373 /  589824 ( 81.10%) | total_pruned =  111451 | shape = (256, 256, 3, 3)
# layer3.0.bn2.weight  | nonzeros =     207 /     256 ( 80.86%) | total_pruned =      49 | shape = (256,)
# layer3.0.bn2.bias    | nonzeros =     240 /     256 ( 93.75%) | total_pruned =      16 | shape = (256,)
# layer3.0.downsample.0.weight | nonzeros =   26608 /   32768 ( 81.20%) | total_pruned =    6160 | shape = (256, 128, 1, 1)
# layer3.0.downsample.1.weight | nonzeros =     207 /     256 ( 80.86%) | total_pruned =      49 | shape = (256,)
# layer3.0.downsample.1.bias | nonzeros =     240 /     256 ( 93.75%) | total_pruned =      16 | shape = (256,)
# layer3.1.conv1.weight | nonzeros =  478354 /  589824 ( 81.10%) | total_pruned =  111470 | shape = (256, 256, 3, 3)
# layer3.1.bn1.weight  | nonzeros =     208 /     256 ( 81.25%) | total_pruned =      48 | shape = (256,)
# layer3.1.bn1.bias    | nonzeros =     231 /     256 ( 90.23%) | total_pruned =      25 | shape = (256,)
# layer3.1.conv2.weight | nonzeros =  478568 /  589824 ( 81.14%) | total_pruned =  111256 | shape = (256, 256, 3, 3)
# layer3.1.bn2.weight  | nonzeros =     207 /     256 ( 80.86%) | total_pruned =      49 | shape = (256,)
# layer3.1.bn2.bias    | nonzeros =     252 /     256 ( 98.44%) | total_pruned =       4 | shape = (256,)
# layer4.0.conv1.weight | nonzeros =  957848 / 1179648 ( 81.20%) | total_pruned =  221800 | shape = (512, 256, 3, 3)
# layer4.0.bn1.weight  | nonzeros =     415 /     512 ( 81.05%) | total_pruned =      97 | shape = (512,)
# layer4.0.bn1.bias    | nonzeros =     461 /     512 ( 90.04%) | total_pruned =      51 | shape = (512,)
# layer4.0.conv2.weight | nonzeros = 1918590 / 2359296 ( 81.32%) | total_pruned =  440706 | shape = (512, 512, 3, 3)
# layer4.0.bn2.weight  | nonzeros =     414 /     512 ( 80.86%) | total_pruned =      98 | shape = (512,)
# layer4.0.bn2.bias    | nonzeros =     473 /     512 ( 92.38%) | total_pruned =      39 | shape = (512,)
# layer4.0.downsample.0.weight | nonzeros =  106622 /  131072 ( 81.35%) | total_pruned =   24450 | shape = (512, 256, 1, 1)
# layer4.0.downsample.1.weight | nonzeros =     414 /     512 ( 80.86%) | total_pruned =      98 | shape = (512,)
# layer4.0.downsample.1.bias | nonzeros =     473 /     512 ( 92.38%) | total_pruned =      39 | shape = (512,)
# layer4.1.conv1.weight | nonzeros = 1914842 / 2359296 ( 81.16%) | total_pruned =  444454 | shape = (512, 512, 3, 3)
# layer4.1.bn1.weight  | nonzeros =     415 /     512 ( 81.05%) | total_pruned =      97 | shape = (512,)
# layer4.1.bn1.bias    | nonzeros =     462 /     512 ( 90.23%) | total_pruned =      50 | shape = (512,)
# layer4.1.conv2.weight | nonzeros = 1915972 / 2359296 ( 81.21%) | total_pruned =  443324 | shape = (512, 512, 3, 3)
# layer4.1.bn2.weight  | nonzeros =     414 /     512 ( 80.86%) | total_pruned =      98 | shape = (512,)
# layer4.1.bn2.bias    | nonzeros =     481 /     512 ( 93.95%) | total_pruned =      31 | shape = (512,)
# fc.weight            | nonzeros =    4149 /    5120 ( 81.04%) | total_pruned =     971 | shape = (10, 512)
# fc.bias              | nonzeros =      10 /      10 (100.00%) | total_pruned =       0 | shape = (10,)
# alive: 9073550, pruned : 2099260, total: 11172810, Compression rate :       1.23x  ( 18.79% pruned)
# Train Epoch: 29/30 Loss: 0.211455 Accuracy: 85.03% Best Accuracy: 85.31%: 100%|████████| 30/30 [36:17<00:00, 72.59s/it]
# --- Pruning Level [1:3/35]: ---
# conv1.weight         | nonzeros =     421 /     576 ( 73.09%) | total_pruned =     155 | shape = (64, 1, 3, 3)
# bn1.weight           | nonzeros =      46 /      64 ( 71.88%) | total_pruned =      18 | shape = (64,)
# bn1.bias             | nonzeros =      57 /      64 ( 89.06%) | total_pruned =       7 | shape = (64,)
# layer1.0.conv1.weight | nonzeros =   27020 /   36864 ( 73.30%) | total_pruned =    9844 | shape = (64, 64, 3, 3)
# layer1.0.bn1.weight  | nonzeros =      46 /      64 ( 71.88%) | total_pruned =      18 | shape = (64,)
# layer1.0.bn1.bias    | nonzeros =      57 /      64 ( 89.06%) | total_pruned =       7 | shape = (64,)
# layer1.0.conv2.weight | nonzeros =   26969 /   36864 ( 73.16%) | total_pruned =    9895 | shape = (64, 64, 3, 3)
# layer1.0.bn2.weight  | nonzeros =      46 /      64 ( 71.88%) | total_pruned =      18 | shape = (64,)
# layer1.0.bn2.bias    | nonzeros =      62 /      64 ( 96.88%) | total_pruned =       2 | shape = (64,)
# layer1.1.conv1.weight | nonzeros =   27015 /   36864 ( 73.28%) | total_pruned =    9849 | shape = (64, 64, 3, 3)
# layer1.1.bn1.weight  | nonzeros =      46 /      64 ( 71.88%) | total_pruned =      18 | shape = (64,)
# layer1.1.bn1.bias    | nonzeros =      57 /      64 ( 89.06%) | total_pruned =       7 | shape = (64,)
# layer1.1.conv2.weight | nonzeros =   26971 /   36864 ( 73.16%) | total_pruned =    9893 | shape = (64, 64, 3, 3)
# layer1.1.bn2.weight  | nonzeros =      46 /      64 ( 71.88%) | total_pruned =      18 | shape = (64,)
# layer1.1.bn2.bias    | nonzeros =      64 /      64 (100.00%) | total_pruned =       0 | shape = (64,)
# layer2.0.conv1.weight | nonzeros =   53888 /   73728 ( 73.09%) | total_pruned =   19840 | shape = (128, 64, 3, 3)
# layer2.0.bn1.weight  | nonzeros =      92 /     128 ( 71.88%) | total_pruned =      36 | shape = (128,)
# layer2.0.bn1.bias    | nonzeros =     115 /     128 ( 89.84%) | total_pruned =      13 | shape = (128,)
# layer2.0.conv2.weight | nonzeros =  107730 /  147456 ( 73.06%) | total_pruned =   39726 | shape = (128, 128, 3, 3)
# layer2.0.bn2.weight  | nonzeros =      92 /     128 ( 71.88%) | total_pruned =      36 | shape = (128,)
# layer2.0.bn2.bias    | nonzeros =     122 /     128 ( 95.31%) | total_pruned =       6 | shape = (128,)
# layer2.0.downsample.0.weight | nonzeros =    5983 /    8192 ( 73.03%) | total_pruned =    2209 | shape = (128, 64, 1, 1)
# layer2.0.downsample.1.weight | nonzeros =      92 /     128 ( 71.88%) | total_pruned =      36 | shape = (128,)
# layer2.0.downsample.1.bias | nonzeros =     122 /     128 ( 95.31%) | total_pruned =       6 | shape = (128,)
# layer2.1.conv1.weight | nonzeros =  107877 /  147456 ( 73.16%) | total_pruned =   39579 | shape = (128, 128, 3, 3)
# layer2.1.bn1.weight  | nonzeros =      92 /     128 ( 71.88%) | total_pruned =      36 | shape = (128,)
# layer2.1.bn1.bias    | nonzeros =     115 /     128 ( 89.84%) | total_pruned =      13 | shape = (128,)
# layer2.1.conv2.weight | nonzeros =  107923 /  147456 ( 73.19%) | total_pruned =   39533 | shape = (128, 128, 3, 3)
# layer2.1.bn2.weight  | nonzeros =      92 /     128 ( 71.88%) | total_pruned =      36 | shape = (128,)
# layer2.1.bn2.bias    | nonzeros =     124 /     128 ( 96.88%) | total_pruned =       4 | shape = (128,)
# layer3.0.conv1.weight | nonzeros =  215637 /  294912 ( 73.12%) | total_pruned =   79275 | shape = (256, 128, 3, 3)
# layer3.0.bn1.weight  | nonzeros =     186 /     256 ( 72.66%) | total_pruned =      70 | shape = (256,)
# layer3.0.bn1.bias    | nonzeros =     230 /     256 ( 89.84%) | total_pruned =      26 | shape = (256,)
# layer3.0.conv2.weight | nonzeros =  430701 /  589824 ( 73.02%) | total_pruned =  159123 | shape = (256, 256, 3, 3)
# layer3.0.bn2.weight  | nonzeros =     186 /     256 ( 72.66%) | total_pruned =      70 | shape = (256,)
# layer3.0.bn2.bias    | nonzeros =     240 /     256 ( 93.75%) | total_pruned =      16 | shape = (256,)
# layer3.0.downsample.0.weight | nonzeros =   23997 /   32768 ( 73.23%) | total_pruned =    8771 | shape = (256, 128, 1, 1)
# layer3.0.downsample.1.weight | nonzeros =     186 /     256 ( 72.66%) | total_pruned =      70 | shape = (256,)
# layer3.0.downsample.1.bias | nonzeros =     240 /     256 ( 93.75%) | total_pruned =      16 | shape = (256,)
# layer3.1.conv1.weight | nonzeros =  430678 /  589824 ( 73.02%) | total_pruned =  159146 | shape = (256, 256, 3, 3)
# layer3.1.bn1.weight  | nonzeros =     187 /     256 ( 73.05%) | total_pruned =      69 | shape = (256,)
# layer3.1.bn1.bias    | nonzeros =     231 /     256 ( 90.23%) | total_pruned =      25 | shape = (256,)
# layer3.1.conv2.weight | nonzeros =  431467 /  589824 ( 73.15%) | total_pruned =  158357 | shape = (256, 256, 3, 3)
# layer3.1.bn2.weight  | nonzeros =     186 /     256 ( 72.66%) | total_pruned =      70 | shape = (256,)
# layer3.1.bn2.bias    | nonzeros =     252 /     256 ( 98.44%) | total_pruned =       4 | shape = (256,)
# layer4.0.conv1.weight | nonzeros =  862272 / 1179648 ( 73.10%) | total_pruned =  317376 | shape = (512, 256, 3, 3)
# layer4.0.bn1.weight  | nonzeros =     373 /     512 ( 72.85%) | total_pruned =     139 | shape = (512,)
# layer4.0.bn1.bias    | nonzeros =     461 /     512 ( 90.04%) | total_pruned =      51 | shape = (512,)
# layer4.0.conv2.weight | nonzeros = 1726875 / 2359296 ( 73.19%) | total_pruned =  632421 | shape = (512, 512, 3, 3)
# layer4.0.bn2.weight  | nonzeros =     372 /     512 ( 72.66%) | total_pruned =     140 | shape = (512,)
# layer4.0.bn2.bias    | nonzeros =     473 /     512 ( 92.38%) | total_pruned =      39 | shape = (512,)
# layer4.0.downsample.0.weight | nonzeros =   96010 /  131072 ( 73.25%) | total_pruned =   35062 | shape = (512, 256, 1, 1)
# layer4.0.downsample.1.weight | nonzeros =     372 /     512 ( 72.66%) | total_pruned =     140 | shape = (512,)
# layer4.0.downsample.1.bias | nonzeros =     473 /     512 ( 92.38%) | total_pruned =      39 | shape = (512,)
# layer4.1.conv1.weight | nonzeros = 1724754 / 2359296 ( 73.10%) | total_pruned =  634542 | shape = (512, 512, 3, 3)
# layer4.1.bn1.weight  | nonzeros =     373 /     512 ( 72.85%) | total_pruned =     139 | shape = (512,)
# layer4.1.bn1.bias    | nonzeros =     462 /     512 ( 90.23%) | total_pruned =      50 | shape = (512,)
# layer4.1.conv2.weight | nonzeros = 1727292 / 2359296 ( 73.21%) | total_pruned =  632004 | shape = (512, 512, 3, 3)
# layer4.1.bn2.weight  | nonzeros =     372 /     512 ( 72.66%) | total_pruned =     140 | shape = (512,)
# layer4.1.bn2.bias    | nonzeros =     481 /     512 ( 93.95%) | total_pruned =      31 | shape = (512,)
# fc.weight            | nonzeros =    3737 /    5120 ( 72.99%) | total_pruned =    1383 | shape = (10, 512)
# fc.bias              | nonzeros =      10 /      10 (100.00%) | total_pruned =       0 | shape = (10,)
# alive: 8173148, pruned : 2999662, total: 11172810, Compression rate :       1.37x  ( 26.85% pruned)
# Train Epoch: 29/30 Loss: 0.348283 Accuracy: 84.92% Best Accuracy: 86.16%: 100%|████████| 30/30 [36:32<00:00, 73.10s/it]
# --- Pruning Level [1:4/35]: ---
# conv1.weight         | nonzeros =     379 /     576 ( 65.80%) | total_pruned =     197 | shape = (64, 1, 3, 3)
# bn1.weight           | nonzeros =      41 /      64 ( 64.06%) | total_pruned =      23 | shape = (64,)
# bn1.bias             | nonzeros =      57 /      64 ( 89.06%) | total_pruned =       7 | shape = (64,)
# layer1.0.conv1.weight | nonzeros =   24329 /   36864 ( 66.00%) | total_pruned =   12535 | shape = (64, 64, 3, 3)
# layer1.0.bn1.weight  | nonzeros =      41 /      64 ( 64.06%) | total_pruned =      23 | shape = (64,)
# layer1.0.bn1.bias    | nonzeros =      57 /      64 ( 89.06%) | total_pruned =       7 | shape = (64,)
# layer1.0.conv2.weight | nonzeros =   24293 /   36864 ( 65.90%) | total_pruned =   12571 | shape = (64, 64, 3, 3)
# layer1.0.bn2.weight  | nonzeros =      41 /      64 ( 64.06%) | total_pruned =      23 | shape = (64,)
# layer1.0.bn2.bias    | nonzeros =      62 /      64 ( 96.88%) | total_pruned =       2 | shape = (64,)
# layer1.1.conv1.weight | nonzeros =   24345 /   36864 ( 66.04%) | total_pruned =   12519 | shape = (64, 64, 3, 3)
# layer1.1.bn1.weight  | nonzeros =      41 /      64 ( 64.06%) | total_pruned =      23 | shape = (64,)
# layer1.1.bn1.bias    | nonzeros =      57 /      64 ( 89.06%) | total_pruned =       7 | shape = (64,)
# layer1.1.conv2.weight | nonzeros =   24312 /   36864 ( 65.95%) | total_pruned =   12552 | shape = (64, 64, 3, 3)
# layer1.1.bn2.weight  | nonzeros =      41 /      64 ( 64.06%) | total_pruned =      23 | shape = (64,)
# layer1.1.bn2.bias    | nonzeros =      64 /      64 (100.00%) | total_pruned =       0 | shape = (64,)
# layer2.0.conv1.weight | nonzeros =   48540 /   73728 ( 65.84%) | total_pruned =   25188 | shape = (128, 64, 3, 3)
# layer2.0.bn1.weight  | nonzeros =      82 /     128 ( 64.06%) | total_pruned =      46 | shape = (128,)
# layer2.0.bn1.bias    | nonzeros =     115 /     128 ( 89.84%) | total_pruned =      13 | shape = (128,)
# layer2.0.conv2.weight | nonzeros =   97021 /  147456 ( 65.80%) | total_pruned =   50435 | shape = (128, 128, 3, 3)
# layer2.0.bn2.weight  | nonzeros =      82 /     128 ( 64.06%) | total_pruned =      46 | shape = (128,)
# layer2.0.bn2.bias    | nonzeros =     122 /     128 ( 95.31%) | total_pruned =       6 | shape = (128,)
# layer2.0.downsample.0.weight | nonzeros =    5389 /    8192 ( 65.78%) | total_pruned =    2803 | shape = (128, 64, 1, 1)
# layer2.0.downsample.1.weight | nonzeros =      82 /     128 ( 64.06%) | total_pruned =      46 | shape = (128,)
# layer2.0.downsample.1.bias | nonzeros =     122 /     128 ( 95.31%) | total_pruned =       6 | shape = (128,)
# layer2.1.conv1.weight | nonzeros =   97197 /  147456 ( 65.92%) | total_pruned =   50259 | shape = (128, 128, 3, 3)
# layer2.1.bn1.weight  | nonzeros =      82 /     128 ( 64.06%) | total_pruned =      46 | shape = (128,)
# layer2.1.bn1.bias    | nonzeros =     115 /     128 ( 89.84%) | total_pruned =      13 | shape = (128,)
# layer2.1.conv2.weight | nonzeros =   97168 /  147456 ( 65.90%) | total_pruned =   50288 | shape = (128, 128, 3, 3)
# layer2.1.bn2.weight  | nonzeros =      82 /     128 ( 64.06%) | total_pruned =      46 | shape = (128,)
# layer2.1.bn2.bias    | nonzeros =     124 /     128 ( 96.88%) | total_pruned =       4 | shape = (128,)
# layer3.0.conv1.weight | nonzeros =  194123 /  294912 ( 65.82%) | total_pruned =  100789 | shape = (256, 128, 3, 3)
# layer3.0.bn1.weight  | nonzeros =     167 /     256 ( 65.23%) | total_pruned =      89 | shape = (256,)
# layer3.0.bn1.bias    | nonzeros =     230 /     256 ( 89.84%) | total_pruned =      26 | shape = (256,)
# layer3.0.conv2.weight | nonzeros =  387971 /  589824 ( 65.78%) | total_pruned =  201853 | shape = (256, 256, 3, 3)
# layer3.0.bn2.weight  | nonzeros =     167 /     256 ( 65.23%) | total_pruned =      89 | shape = (256,)
# layer3.0.bn2.bias    | nonzeros =     240 /     256 ( 93.75%) | total_pruned =      16 | shape = (256,)
# layer3.0.downsample.0.weight | nonzeros =   21604 /   32768 ( 65.93%) | total_pruned =   11164 | shape = (256, 128, 1, 1)
# layer3.0.downsample.1.weight | nonzeros =     167 /     256 ( 65.23%) | total_pruned =      89 | shape = (256,)
# layer3.0.downsample.1.bias | nonzeros =     240 /     256 ( 93.75%) | total_pruned =      16 | shape = (256,)
# layer3.1.conv1.weight | nonzeros =  387749 /  589824 ( 65.74%) | total_pruned =  202075 | shape = (256, 256, 3, 3)
# layer3.1.bn1.weight  | nonzeros =     168 /     256 ( 65.62%) | total_pruned =      88 | shape = (256,)
# layer3.1.bn1.bias    | nonzeros =     231 /     256 ( 90.23%) | total_pruned =      25 | shape = (256,)
# layer3.1.conv2.weight | nonzeros =  389002 /  589824 ( 65.95%) | total_pruned =  200822 | shape = (256, 256, 3, 3)
# layer3.1.bn2.weight  | nonzeros =     167 /     256 ( 65.23%) | total_pruned =      89 | shape = (256,)
# layer3.1.bn2.bias    | nonzeros =     252 /     256 ( 98.44%) | total_pruned =       4 | shape = (256,)
# layer4.0.conv1.weight | nonzeros =  777175 / 1179648 ( 65.88%) | total_pruned =  402473 | shape = (512, 256, 3, 3)
# layer4.0.bn1.weight  | nonzeros =     335 /     512 ( 65.43%) | total_pruned =     177 | shape = (512,)
# layer4.0.bn1.bias    | nonzeros =     461 /     512 ( 90.04%) | total_pruned =      51 | shape = (512,)
# layer4.0.conv2.weight | nonzeros = 1554988 / 2359296 ( 65.91%) | total_pruned =  804308 | shape = (512, 512, 3, 3)
# layer4.0.bn2.weight  | nonzeros =     334 /     512 ( 65.23%) | total_pruned =     178 | shape = (512,)
# layer4.0.bn2.bias    | nonzeros =     473 /     512 ( 92.38%) | total_pruned =      39 | shape = (512,)
# layer4.0.downsample.0.weight | nonzeros =   86528 /  131072 ( 66.02%) | total_pruned =   44544 | shape = (512, 256, 1, 1)
# layer4.0.downsample.1.weight | nonzeros =     334 /     512 ( 65.23%) | total_pruned =     178 | shape = (512,)
# layer4.0.downsample.1.bias | nonzeros =     473 /     512 ( 92.38%) | total_pruned =      39 | shape = (512,)
# layer4.1.conv1.weight | nonzeros = 1553642 / 2359296 ( 65.85%) | total_pruned =  805654 | shape = (512, 512, 3, 3)
# layer4.1.bn1.weight  | nonzeros =     335 /     512 ( 65.43%) | total_pruned =     177 | shape = (512,)
# layer4.1.bn1.bias    | nonzeros =     462 /     512 ( 90.23%) | total_pruned =      50 | shape = (512,)
# layer4.1.conv2.weight | nonzeros = 1555664 / 2359296 ( 65.94%) | total_pruned =  803632 | shape = (512, 512, 3, 3)
# layer4.1.bn2.weight  | nonzeros =     334 /     512 ( 65.23%) | total_pruned =     178 | shape = (512,)
# layer4.1.bn2.bias    | nonzeros =     481 /     512 ( 93.95%) | total_pruned =      31 | shape = (512,)
# fc.weight            | nonzeros =    3364 /    5120 ( 65.70%) | total_pruned =    1756 | shape = (10, 512)
# fc.bias              | nonzeros =      10 /      10 (100.00%) | total_pruned =       0 | shape = (10,)
# alive: 7362354, pruned : 3810456, total: 11172810, Compression rate :       1.52x  ( 34.10% pruned)
# Train Epoch: 29/30 Loss: 0.348384 Accuracy: 86.52% Best Accuracy: 87.26%: 100%|████████| 30/30 [36:20<00:00, 72.67s/it]
# --- Pruning Level [1:5/35]: ---
# conv1.weight         | nonzeros =     344 /     576 ( 59.72%) | total_pruned =     232 | shape = (64, 1, 3, 3)
# bn1.weight           | nonzeros =      37 /      64 ( 57.81%) | total_pruned =      27 | shape = (64,)
# bn1.bias             | nonzeros =      57 /      64 ( 89.06%) | total_pruned =       7 | shape = (64,)
# layer1.0.conv1.weight | nonzeros =   21929 /   36864 ( 59.49%) | total_pruned =   14935 | shape = (64, 64, 3, 3)
# layer1.0.bn1.weight  | nonzeros =      37 /      64 ( 57.81%) | total_pruned =      27 | shape = (64,)
# layer1.0.bn1.bias    | nonzeros =      57 /      64 ( 89.06%) | total_pruned =       7 | shape = (64,)
# layer1.0.conv2.weight | nonzeros =   21874 /   36864 ( 59.34%) | total_pruned =   14990 | shape = (64, 64, 3, 3)
# layer1.0.bn2.weight  | nonzeros =      37 /      64 ( 57.81%) | total_pruned =      27 | shape = (64,)
# layer1.0.bn2.bias    | nonzeros =      62 /      64 ( 96.88%) | total_pruned =       2 | shape = (64,)
# layer1.1.conv1.weight | nonzeros =   21921 /   36864 ( 59.46%) | total_pruned =   14943 | shape = (64, 64, 3, 3)
# layer1.1.bn1.weight  | nonzeros =      37 /      64 ( 57.81%) | total_pruned =      27 | shape = (64,)
# layer1.1.bn1.bias    | nonzeros =      57 /      64 ( 89.06%) | total_pruned =       7 | shape = (64,)
# layer1.1.conv2.weight | nonzeros =   21896 /   36864 ( 59.40%) | total_pruned =   14968 | shape = (64, 64, 3, 3)
# layer1.1.bn2.weight  | nonzeros =      37 /      64 ( 57.81%) | total_pruned =      27 | shape = (64,)
# layer1.1.bn2.bias    | nonzeros =      64 /      64 (100.00%) | total_pruned =       0 | shape = (64,)
# layer2.0.conv1.weight | nonzeros =   43689 /   73728 ( 59.26%) | total_pruned =   30039 | shape = (128, 64, 3, 3)
# layer2.0.bn1.weight  | nonzeros =      73 /     128 ( 57.03%) | total_pruned =      55 | shape = (128,)
# layer2.0.bn1.bias    | nonzeros =     115 /     128 ( 89.84%) | total_pruned =      13 | shape = (128,)
# layer2.0.conv2.weight | nonzeros =   87397 /  147456 ( 59.27%) | total_pruned =   60059 | shape = (128, 128, 3, 3)
# layer2.0.bn2.weight  | nonzeros =      73 /     128 ( 57.03%) | total_pruned =      55 | shape = (128,)
# layer2.0.bn2.bias    | nonzeros =     122 /     128 ( 95.31%) | total_pruned =       6 | shape = (128,)
# layer2.0.downsample.0.weight | nonzeros =    4850 /    8192 ( 59.20%) | total_pruned =    3342 | shape = (128, 64, 1, 1)
# layer2.0.downsample.1.weight | nonzeros =      73 /     128 ( 57.03%) | total_pruned =      55 | shape = (128,)
# layer2.0.downsample.1.bias | nonzeros =     122 /     128 ( 95.31%) | total_pruned =       6 | shape = (128,)
# layer2.1.conv1.weight | nonzeros =   87530 /  147456 ( 59.36%) | total_pruned =   59926 | shape = (128, 128, 3, 3)
# layer2.1.bn1.weight  | nonzeros =      73 /     128 ( 57.03%) | total_pruned =      55 | shape = (128,)
# layer2.1.bn1.bias    | nonzeros =     115 /     128 ( 89.84%) | total_pruned =      13 | shape = (128,)
# layer2.1.conv2.weight | nonzeros =   87561 /  147456 ( 59.38%) | total_pruned =   59895 | shape = (128, 128, 3, 3)
# layer2.1.bn2.weight  | nonzeros =      73 /     128 ( 57.03%) | total_pruned =      55 | shape = (128,)
# layer2.1.bn2.bias    | nonzeros =     124 /     128 ( 96.88%) | total_pruned =       4 | shape = (128,)
# layer3.0.conv1.weight | nonzeros =  174934 /  294912 ( 59.32%) | total_pruned =  119978 | shape = (256, 128, 3, 3)
# layer3.0.bn1.weight  | nonzeros =     150 /     256 ( 58.59%) | total_pruned =     106 | shape = (256,)
# layer3.0.bn1.bias    | nonzeros =     230 /     256 ( 89.84%) | total_pruned =      26 | shape = (256,)
# layer3.0.conv2.weight | nonzeros =  349764 /  589824 ( 59.30%) | total_pruned =  240060 | shape = (256, 256, 3, 3)
# layer3.0.bn2.weight  | nonzeros =     150 /     256 ( 58.59%) | total_pruned =     106 | shape = (256,)
# layer3.0.bn2.bias    | nonzeros =     240 /     256 ( 93.75%) | total_pruned =      16 | shape = (256,)
# layer3.0.downsample.0.weight | nonzeros =   19471 /   32768 ( 59.42%) | total_pruned =   13297 | shape = (256, 128, 1, 1)
# layer3.0.downsample.1.weight | nonzeros =     150 /     256 ( 58.59%) | total_pruned =     106 | shape = (256,)
# layer3.0.downsample.1.bias | nonzeros =     240 /     256 ( 93.75%) | total_pruned =      16 | shape = (256,)
# layer3.1.conv1.weight | nonzeros =  348977 /  589824 ( 59.17%) | total_pruned =  240847 | shape = (256, 256, 3, 3)
# layer3.1.bn1.weight  | nonzeros =     151 /     256 ( 58.98%) | total_pruned =     105 | shape = (256,)
# layer3.1.bn1.bias    | nonzeros =     231 /     256 ( 90.23%) | total_pruned =      25 | shape = (256,)
# layer3.1.conv2.weight | nonzeros =  350538 /  589824 ( 59.43%) | total_pruned =  239286 | shape = (256, 256, 3, 3)
# layer3.1.bn2.weight  | nonzeros =     150 /     256 ( 58.59%) | total_pruned =     106 | shape = (256,)
# layer3.1.bn2.bias    | nonzeros =     252 /     256 ( 98.44%) | total_pruned =       4 | shape = (256,)
# layer4.0.conv1.weight | nonzeros =  700632 / 1179648 ( 59.39%) | total_pruned =  479016 | shape = (512, 256, 3, 3)
# layer4.0.bn1.weight  | nonzeros =     301 /     512 ( 58.79%) | total_pruned =     211 | shape = (512,)
# layer4.0.bn1.bias    | nonzeros =     461 /     512 ( 90.04%) | total_pruned =      51 | shape = (512,)
# layer4.0.conv2.weight | nonzeros = 1400051 / 2359296 ( 59.34%) | total_pruned =  959245 | shape = (512, 512, 3, 3)
# layer4.0.bn2.weight  | nonzeros =     300 /     512 ( 58.59%) | total_pruned =     212 | shape = (512,)
# layer4.0.bn2.bias    | nonzeros =     473 /     512 ( 92.38%) | total_pruned =      39 | shape = (512,)
# layer4.0.downsample.0.weight | nonzeros =   77882 /  131072 ( 59.42%) | total_pruned =   53190 | shape = (512, 256, 1, 1)
# layer4.0.downsample.1.weight | nonzeros =     300 /     512 ( 58.59%) | total_pruned =     212 | shape = (512,)
# layer4.0.downsample.1.bias | nonzeros =     473 /     512 ( 92.38%) | total_pruned =      39 | shape = (512,)
# layer4.1.conv1.weight | nonzeros = 1400665 / 2359296 ( 59.37%) | total_pruned =  958631 | shape = (512, 512, 3, 3)
# layer4.1.bn1.weight  | nonzeros =     301 /     512 ( 58.79%) | total_pruned =     211 | shape = (512,)
# layer4.1.bn1.bias    | nonzeros =     462 /     512 ( 90.23%) | total_pruned =      50 | shape = (512,)
# layer4.1.conv2.weight | nonzeros = 1400949 / 2359296 ( 59.38%) | total_pruned =  958347 | shape = (512, 512, 3, 3)
# layer4.1.bn2.weight  | nonzeros =     300 /     512 ( 58.59%) | total_pruned =     212 | shape = (512,)
# layer4.1.bn2.bias    | nonzeros =     481 /     512 ( 93.95%) | total_pruned =      31 | shape = (512,)
# fc.weight            | nonzeros =    3032 /    5120 ( 59.22%) | total_pruned =    2088 | shape = (10, 512)
# fc.bias              | nonzeros =      10 /      10 (100.00%) | total_pruned =       0 | shape = (10,)
# alive: 6633137, pruned : 4539673, total: 11172810, Compression rate :       1.68x  ( 40.63% pruned)
# Train Epoch: 29/30 Loss: 0.525286 Accuracy: 10.29% Best Accuracy: 85.31%: 100%|████████| 30/30 [36:19<00:00, 72.66s/it]
# --- Pruning Level [1:6/35]: ---
# conv1.weight         | nonzeros =     311 /     576 ( 53.99%) | total_pruned =     265 | shape = (64, 1, 3, 3)
# bn1.weight           | nonzeros =      33 /      64 ( 51.56%) | total_pruned =      31 | shape = (64,)
# bn1.bias             | nonzeros =      57 /      64 ( 89.06%) | total_pruned =       7 | shape = (64,)
# layer1.0.conv1.weight | nonzeros =   19759 /   36864 ( 53.60%) | total_pruned =   17105 | shape = (64, 64, 3, 3)
# layer1.0.bn1.weight  | nonzeros =      33 /      64 ( 51.56%) | total_pruned =      31 | shape = (64,)
# layer1.0.bn1.bias    | nonzeros =      57 /      64 ( 89.06%) | total_pruned =       7 | shape = (64,)
# layer1.0.conv2.weight | nonzeros =   19745 /   36864 ( 53.56%) | total_pruned =   17119 | shape = (64, 64, 3, 3)
# layer1.0.bn2.weight  | nonzeros =      33 /      64 ( 51.56%) | total_pruned =      31 | shape = (64,)
# layer1.0.bn2.bias    | nonzeros =      62 /      64 ( 96.88%) | total_pruned =       2 | shape = (64,)
# layer1.1.conv1.weight | nonzeros =   19745 /   36864 ( 53.56%) | total_pruned =   17119 | shape = (64, 64, 3, 3)
# layer1.1.bn1.weight  | nonzeros =      33 /      64 ( 51.56%) | total_pruned =      31 | shape = (64,)
# layer1.1.bn1.bias    | nonzeros =      57 /      64 ( 89.06%) | total_pruned =       7 | shape = (64,)
# layer1.1.conv2.weight | nonzeros =   19722 /   36864 ( 53.50%) | total_pruned =   17142 | shape = (64, 64, 3, 3)
# layer1.1.bn2.weight  | nonzeros =      33 /      64 ( 51.56%) | total_pruned =      31 | shape = (64,)
# layer1.1.bn2.bias    | nonzeros =      64 /      64 (100.00%) | total_pruned =       0 | shape = (64,)
# layer2.0.conv1.weight | nonzeros =   39323 /   73728 ( 53.34%) | total_pruned =   34405 | shape = (128, 64, 3, 3)
# layer2.0.bn1.weight  | nonzeros =      65 /     128 ( 50.78%) | total_pruned =      63 | shape = (128,)
# layer2.0.bn1.bias    | nonzeros =     115 /     128 ( 89.84%) | total_pruned =      13 | shape = (128,)
# layer2.0.conv2.weight | nonzeros =   78814 /  147456 ( 53.45%) | total_pruned =   68642 | shape = (128, 128, 3, 3)
# layer2.0.bn2.weight  | nonzeros =      65 /     128 ( 50.78%) | total_pruned =      63 | shape = (128,)
# layer2.0.bn2.bias    | nonzeros =     122 /     128 ( 95.31%) | total_pruned =       6 | shape = (128,)
# layer2.0.downsample.0.weight | nonzeros =    4370 /    8192 ( 53.34%) | total_pruned =    3822 | shape = (128, 64, 1, 1)
# layer2.0.downsample.1.weight | nonzeros =      65 /     128 ( 50.78%) | total_pruned =      63 | shape = (128,)
# layer2.0.downsample.1.bias | nonzeros =     122 /     128 ( 95.31%) | total_pruned =       6 | shape = (128,)
# layer2.1.conv1.weight | nonzeros =   78950 /  147456 ( 53.54%) | total_pruned =   68506 | shape = (128, 128, 3, 3)
# layer2.1.bn1.weight  | nonzeros =      65 /     128 ( 50.78%) | total_pruned =      63 | shape = (128,)
# layer2.1.bn1.bias    | nonzeros =     115 /     128 ( 89.84%) | total_pruned =      13 | shape = (128,)
# layer2.1.conv2.weight | nonzeros =   78900 /  147456 ( 53.51%) | total_pruned =   68556 | shape = (128, 128, 3, 3)
# layer2.1.bn2.weight  | nonzeros =      65 /     128 ( 50.78%) | total_pruned =      63 | shape = (128,)
# layer2.1.bn2.bias    | nonzeros =     124 /     128 ( 96.88%) | total_pruned =       4 | shape = (128,)
# layer3.0.conv1.weight | nonzeros =  157752 /  294912 ( 53.49%) | total_pruned =  137160 | shape = (256, 128, 3, 3)
# layer3.0.bn1.weight  | nonzeros =     135 /     256 ( 52.73%) | total_pruned =     121 | shape = (256,)
# layer3.0.bn1.bias    | nonzeros =     230 /     256 ( 89.84%) | total_pruned =      26 | shape = (256,)
# layer3.0.conv2.weight | nonzeros =  315093 /  589824 ( 53.42%) | total_pruned =  274731 | shape = (256, 256, 3, 3)
# layer3.0.bn2.weight  | nonzeros =     135 /     256 ( 52.73%) | total_pruned =     121 | shape = (256,)
# layer3.0.bn2.bias    | nonzeros =     240 /     256 ( 93.75%) | total_pruned =      16 | shape = (256,)
# layer3.0.downsample.0.weight | nonzeros =   17529 /   32768 ( 53.49%) | total_pruned =   15239 | shape = (256, 128, 1, 1)
# layer3.0.downsample.1.weight | nonzeros =     135 /     256 ( 52.73%) | total_pruned =     121 | shape = (256,)
# layer3.0.downsample.1.bias | nonzeros =     240 /     256 ( 93.75%) | total_pruned =      16 | shape = (256,)
# layer3.1.conv1.weight | nonzeros =  314580 /  589824 ( 53.33%) | total_pruned =  275244 | shape = (256, 256, 3, 3)
# layer3.1.bn1.weight  | nonzeros =     136 /     256 ( 53.12%) | total_pruned =     120 | shape = (256,)
# layer3.1.bn1.bias    | nonzeros =     231 /     256 ( 90.23%) | total_pruned =      25 | shape = (256,)
# layer3.1.conv2.weight | nonzeros =  315985 /  589824 ( 53.57%) | total_pruned =  273839 | shape = (256, 256, 3, 3)
# layer3.1.bn2.weight  | nonzeros =     135 /     256 ( 52.73%) | total_pruned =     121 | shape = (256,)
# layer3.1.bn2.bias    | nonzeros =     252 /     256 ( 98.44%) | total_pruned =       4 | shape = (256,)
# layer4.0.conv1.weight | nonzeros =  631528 / 1179648 ( 53.54%) | total_pruned =  548120 | shape = (512, 256, 3, 3)
# layer4.0.bn1.weight  | nonzeros =     271 /     512 ( 52.93%) | total_pruned =     241 | shape = (512,)
# layer4.0.bn1.bias    | nonzeros =     461 /     512 ( 90.04%) | total_pruned =      51 | shape = (512,)
# layer4.0.conv2.weight | nonzeros = 1261549 / 2359296 ( 53.47%) | total_pruned = 1097747 | shape = (512, 512, 3, 3)
# layer4.0.bn2.weight  | nonzeros =     270 /     512 ( 52.73%) | total_pruned =     242 | shape = (512,)
# layer4.0.bn2.bias    | nonzeros =     473 /     512 ( 92.38%) | total_pruned =      39 | shape = (512,)
# layer4.0.downsample.0.weight | nonzeros =   70217 /  131072 ( 53.57%) | total_pruned =   60855 | shape = (512, 256, 1, 1)
# layer4.0.downsample.1.weight | nonzeros =     270 /     512 ( 52.73%) | total_pruned =     242 | shape = (512,)
# layer4.0.downsample.1.bias | nonzeros =     473 /     512 ( 92.38%) | total_pruned =      39 | shape = (512,)
# layer4.1.conv1.weight | nonzeros = 1261389 / 2359296 ( 53.46%) | total_pruned = 1097907 | shape = (512, 512, 3, 3)
# layer4.1.bn1.weight  | nonzeros =     271 /     512 ( 52.93%) | total_pruned =     241 | shape = (512,)
# layer4.1.bn1.bias    | nonzeros =     462 /     512 ( 90.23%) | total_pruned =      50 | shape = (512,)
# ...
# layer4.0.conv1.weight | nonzeros =   41491 / 1179648 (  3.52%) | total_pruned = 1138157 | shape = (512, 256, 3, 3)
# layer4.0.bn1.weight  | nonzeros =      14 /     512 (  2.73%) | total_pruned =     498 | shape = (512,)
# layer4.0.bn1.bias    | nonzeros =     461 /     512 ( 90.04%) | total_pruned =      51 | shape = (512,)
# layer4.0.conv2.weight | nonzeros =   82667 / 2359296 (  3.50%) | total_pruned = 2276629 | shape = (512, 512, 3, 3)
# layer4.0.bn2.weight  | nonzeros =      14 /     512 (  2.73%) | total_pruned =     498 | shape = (512,)
# layer4.0.bn2.bias    | nonzeros =     473 /     512 ( 92.38%) | total_pruned =      39 | shape = (512,)
# layer4.0.downsample.0.weight | nonzeros =    4713 /  131072 (  3.60%) | total_pruned =  126359 | shape = (512, 256, 1, 1)
# layer4.0.downsample.1.weight | nonzeros =      14 /     512 (  2.73%) | total_pruned =     498 | shape = (512,)
# layer4.0.downsample.1.bias | nonzeros =     473 /     512 ( 92.38%) | total_pruned =      39 | shape = (512,)
# layer4.1.conv1.weight | nonzeros =   82540 / 2359296 (  3.50%) | total_pruned = 2276756 | shape = (512, 512, 3, 3)
# layer4.1.bn1.weight  | nonzeros =      14 /     512 (  2.73%) | total_pruned =     498 | shape = (512,)
# layer4.1.bn1.bias    | nonzeros =     462 /     512 ( 90.23%) | total_pruned =      50 | shape = (512,)
# layer4.1.conv2.weight | nonzeros =   82523 / 2359296 (  3.50%) | total_pruned = 2276773 | shape = (512, 512, 3, 3)
# layer4.1.bn2.weight  | nonzeros =      14 /     512 (  2.73%) | total_pruned =     498 | shape = (512,)
# layer4.1.bn2.bias    | nonzeros =     481 /     512 ( 93.95%) | total_pruned =      31 | shape = (512,)
# fc.weight            | nonzeros =     175 /    5120 (  3.42%) | total_pruned =    4945 | shape = (10, 512)
# fc.bias              | nonzeros =      10 /      10 (100.00%) | total_pruned =       0 | shape = (10,)
# alive: 396383, pruned : 10776427, total: 11172810, Compression rate :      28.19x  ( 96.45% pruned)
# Train Epoch: 29/30 Loss: 1.379586 Accuracy: 50.84% Best Accuracy: 50.84%: 100%|████████| 30/30 [34:05<00:00, 68.17s/it]
# --- Pruning Level [1:33/35]: ---
# conv1.weight         | nonzeros =      16 /     576 (  2.78%) | total_pruned =     560 | shape = (64, 1, 3, 3)
# bn1.weight           | nonzeros =       1 /      64 (  1.56%) | total_pruned =      63 | shape = (64,)
# bn1.bias             | nonzeros =      57 /      64 ( 89.06%) | total_pruned =       7 | shape = (64,)
# layer1.0.conv1.weight | nonzeros =    1181 /   36864 (  3.20%) | total_pruned =   35683 | shape = (64, 64, 3, 3)
# layer1.0.bn1.weight  | nonzeros =       1 /      64 (  1.56%) | total_pruned =      63 | shape = (64,)
# layer1.0.bn1.bias    | nonzeros =      57 /      64 ( 89.06%) | total_pruned =       7 | shape = (64,)
# layer1.0.conv2.weight | nonzeros =    1188 /   36864 (  3.22%) | total_pruned =   35676 | shape = (64, 64, 3, 3)
# layer1.0.bn2.weight  | nonzeros =       1 /      64 (  1.56%) | total_pruned =      63 | shape = (64,)
# layer1.0.bn2.bias    | nonzeros =      62 /      64 ( 96.88%) | total_pruned =       2 | shape = (64,)
# layer1.1.conv1.weight | nonzeros =    1204 /   36864 (  3.27%) | total_pruned =   35660 | shape = (64, 64, 3, 3)
# layer1.1.bn1.weight  | nonzeros =       1 /      64 (  1.56%) | total_pruned =      63 | shape = (64,)
# layer1.1.bn1.bias    | nonzeros =      57 /      64 ( 89.06%) | total_pruned =       7 | shape = (64,)
# layer1.1.conv2.weight | nonzeros =    1193 /   36864 (  3.24%) | total_pruned =   35671 | shape = (64, 64, 3, 3)
# layer1.1.bn2.weight  | nonzeros =       1 /      64 (  1.56%) | total_pruned =      63 | shape = (64,)
# layer1.1.bn2.bias    | nonzeros =      64 /      64 (100.00%) | total_pruned =       0 | shape = (64,)
# layer2.0.conv1.weight | nonzeros =    2348 /   73728 (  3.18%) | total_pruned =   71380 | shape = (128, 64, 3, 3)
# layer2.0.bn1.weight  | nonzeros =       1 /     128 (  0.78%) | total_pruned =     127 | shape = (128,)
# layer2.0.bn1.bias    | nonzeros =     115 /     128 ( 89.84%) | total_pruned =      13 | shape = (128,)
# layer2.0.conv2.weight | nonzeros =    4706 /  147456 (  3.19%) | total_pruned =  142750 | shape = (128, 128, 3, 3)
# layer2.0.bn2.weight  | nonzeros =       1 /     128 (  0.78%) | total_pruned =     127 | shape = (128,)
# layer2.0.bn2.bias    | nonzeros =     122 /     128 ( 95.31%) | total_pruned =       6 | shape = (128,)
# layer2.0.downsample.0.weight | nonzeros =     267 /    8192 (  3.26%) | total_pruned =    7925 | shape = (128, 64, 1, 1)
# layer2.0.downsample.1.weight | nonzeros =       1 /     128 (  0.78%) | total_pruned =     127 | shape = (128,)
# layer2.0.downsample.1.bias | nonzeros =     122 /     128 ( 95.31%) | total_pruned =       6 | shape = (128,)
# layer2.1.conv1.weight | nonzeros =    4694 /  147456 (  3.18%) | total_pruned =  142762 | shape = (128, 128, 3, 3)
# layer2.1.bn1.weight  | nonzeros =       1 /     128 (  0.78%) | total_pruned =     127 | shape = (128,)
# layer2.1.bn1.bias    | nonzeros =     115 /     128 ( 89.84%) | total_pruned =      13 | shape = (128,)
# layer2.1.conv2.weight | nonzeros =    4691 /  147456 (  3.18%) | total_pruned =  142765 | shape = (128, 128, 3, 3)
# layer2.1.bn2.weight  | nonzeros =       1 /     128 (  0.78%) | total_pruned =     127 | shape = (128,)
# layer2.1.bn2.bias    | nonzeros =     124 /     128 ( 96.88%) | total_pruned =       4 | shape = (128,)
# layer3.0.conv1.weight | nonzeros =    9336 /  294912 (  3.17%) | total_pruned =  285576 | shape = (256, 128, 3, 3)
# layer3.0.bn1.weight  | nonzeros =       5 /     256 (  1.95%) | total_pruned =     251 | shape = (256,)
# layer3.0.bn1.bias    | nonzeros =     230 /     256 ( 89.84%) | total_pruned =      26 | shape = (256,)
# layer3.0.conv2.weight | nonzeros =   18618 /  589824 (  3.16%) | total_pruned =  571206 | shape = (256, 256, 3, 3)
# layer3.0.bn2.weight  | nonzeros =       5 /     256 (  1.95%) | total_pruned =     251 | shape = (256,)
# layer3.0.bn2.bias    | nonzeros =     240 /     256 ( 93.75%) | total_pruned =      16 | shape = (256,)
# layer3.0.downsample.0.weight | nonzeros =    1078 /   32768 (  3.29%) | total_pruned =   31690 | shape = (256, 128, 1, 1)
# layer3.0.downsample.1.weight | nonzeros =       5 /     256 (  1.95%) | total_pruned =     251 | shape = (256,)
# layer3.0.downsample.1.bias | nonzeros =     240 /     256 ( 93.75%) | total_pruned =      16 | shape = (256,)
# layer3.1.conv1.weight | nonzeros =   18616 /  589824 (  3.16%) | total_pruned =  571208 | shape = (256, 256, 3, 3)
# layer3.1.bn1.weight  | nonzeros =       5 /     256 (  1.95%) | total_pruned =     251 | shape = (256,)
# layer3.1.bn1.bias    | nonzeros =     231 /     256 ( 90.23%) | total_pruned =      25 | shape = (256,)
# layer3.1.conv2.weight | nonzeros =   18812 /  589824 (  3.19%) | total_pruned =  571012 | shape = (256, 256, 3, 3)
# layer3.1.bn2.weight  | nonzeros =       5 /     256 (  1.95%) | total_pruned =     251 | shape = (256,)
# layer3.1.bn2.bias    | nonzeros =     252 /     256 ( 98.44%) | total_pruned =       4 | shape = (256,)
# layer4.0.conv1.weight | nonzeros =   37347 / 1179648 (  3.17%) | total_pruned = 1142301 | shape = (512, 256, 3, 3)
# layer4.0.bn1.weight  | nonzeros =      12 /     512 (  2.34%) | total_pruned =     500 | shape = (512,)
# layer4.0.bn1.bias    | nonzeros =     461 /     512 ( 90.04%) | total_pruned =      51 | shape = (512,)
# layer4.0.conv2.weight | nonzeros =   74418 / 2359296 (  3.15%) | total_pruned = 2284878 | shape = (512, 512, 3, 3)
# layer4.0.bn2.weight  | nonzeros =      12 /     512 (  2.34%) | total_pruned =     500 | shape = (512,)
# layer4.0.bn2.bias    | nonzeros =     473 /     512 ( 92.38%) | total_pruned =      39 | shape = (512,)
# layer4.0.downsample.0.weight | nonzeros =    4241 /  131072 (  3.24%) | total_pruned =  126831 | shape = (512, 256, 1, 1)
# layer4.0.downsample.1.weight | nonzeros =      12 /     512 (  2.34%) | total_pruned =     500 | shape = (512,)
# layer4.0.downsample.1.bias | nonzeros =     473 /     512 ( 92.38%) | total_pruned =      39 | shape = (512,)
# layer4.1.conv1.weight | nonzeros =   74293 / 2359296 (  3.15%) | total_pruned = 2285003 | shape = (512, 512, 3, 3)
# layer4.1.bn1.weight  | nonzeros =      12 /     512 (  2.34%) | total_pruned =     500 | shape = (512,)
# layer4.1.bn1.bias    | nonzeros =     462 /     512 ( 90.23%) | total_pruned =      50 | shape = (512,)
# layer4.1.conv2.weight | nonzeros =   74272 / 2359296 (  3.15%) | total_pruned = 2285024 | shape = (512, 512, 3, 3)
# layer4.1.bn2.weight  | nonzeros =      12 /     512 (  2.34%) | total_pruned =     500 | shape = (512,)
# layer4.1.bn2.bias    | nonzeros =     481 /     512 ( 93.95%) | total_pruned =      31 | shape = (512,)
# fc.weight            | nonzeros =     157 /    5120 (  3.07%) | total_pruned =    4963 | shape = (10, 512)
# fc.bias              | nonzeros =      10 /      10 (100.00%) | total_pruned =       0 | shape = (10,)
# alive: 357219, pruned : 10815591, total: 11172810, Compression rate :      31.28x  ( 96.80% pruned)
# Train Epoch: 29/30 Loss: 1.461354 Accuracy: 49.26% Best Accuracy: 50.45%: 100%|████████| 30/30 [33:53<00:00, 67.78s/it]
# --- Pruning Level [1:34/35]: ---
# conv1.weight         | nonzeros =      14 /     576 (  2.43%) | total_pruned =     562 | shape = (64, 1, 3, 3)
# bn1.weight           | nonzeros =       1 /      64 (  1.56%) | total_pruned =      63 | shape = (64,)
# bn1.bias             | nonzeros =      57 /      64 ( 89.06%) | total_pruned =       7 | shape = (64,)
# layer1.0.conv1.weight | nonzeros =    1063 /   36864 (  2.88%) | total_pruned =   35801 | shape = (64, 64, 3, 3)
# layer1.0.bn1.weight  | nonzeros =       1 /      64 (  1.56%) | total_pruned =      63 | shape = (64,)
# layer1.0.bn1.bias    | nonzeros =      57 /      64 ( 89.06%) | total_pruned =       7 | shape = (64,)
# layer1.0.conv2.weight | nonzeros =    1069 /   36864 (  2.90%) | total_pruned =   35795 | shape = (64, 64, 3, 3)
# layer1.0.bn2.weight  | nonzeros =       1 /      64 (  1.56%) | total_pruned =      63 | shape = (64,)
# layer1.0.bn2.bias    | nonzeros =      62 /      64 ( 96.88%) | total_pruned =       2 | shape = (64,)
# layer1.1.conv1.weight | nonzeros =    1084 /   36864 (  2.94%) | total_pruned =   35780 | shape = (64, 64, 3, 3)
# layer1.1.bn1.weight  | nonzeros =       1 /      64 (  1.56%) | total_pruned =      63 | shape = (64,)
# layer1.1.bn1.bias    | nonzeros =      57 /      64 ( 89.06%) | total_pruned =       7 | shape = (64,)
# layer1.1.conv2.weight | nonzeros =    1073 /   36864 (  2.91%) | total_pruned =   35791 | shape = (64, 64, 3, 3)
# layer1.1.bn2.weight  | nonzeros =       1 /      64 (  1.56%) | total_pruned =      63 | shape = (64,)
# layer1.1.bn2.bias    | nonzeros =      64 /      64 (100.00%) | total_pruned =       0 | shape = (64,)
# layer2.0.conv1.weight | nonzeros =    2113 /   73728 (  2.87%) | total_pruned =   71615 | shape = (128, 64, 3, 3)
# layer2.0.bn1.weight  | nonzeros =       1 /     128 (  0.78%) | total_pruned =     127 | shape = (128,)
# layer2.0.bn1.bias    | nonzeros =     115 /     128 ( 89.84%) | total_pruned =      13 | shape = (128,)
# layer2.0.conv2.weight | nonzeros =    4235 /  147456 (  2.87%) | total_pruned =  143221 | shape = (128, 128, 3, 3)
# layer2.0.bn2.weight  | nonzeros =       1 /     128 (  0.78%) | total_pruned =     127 | shape = (128,)
# layer2.0.bn2.bias    | nonzeros =     122 /     128 ( 95.31%) | total_pruned =       6 | shape = (128,)
# layer2.0.downsample.0.weight | nonzeros =     240 /    8192 (  2.93%) | total_pruned =    7952 | shape = (128, 64, 1, 1)
# layer2.0.downsample.1.weight | nonzeros =       1 /     128 (  0.78%) | total_pruned =     127 | shape = (128,)
# layer2.0.downsample.1.bias | nonzeros =     122 /     128 ( 95.31%) | total_pruned =       6 | shape = (128,)
# layer2.1.conv1.weight | nonzeros =    4224 /  147456 (  2.86%) | total_pruned =  143232 | shape = (128, 128, 3, 3)
# layer2.1.bn1.weight  | nonzeros =       1 /     128 (  0.78%) | total_pruned =     127 | shape = (128,)
# layer2.1.bn1.bias    | nonzeros =     115 /     128 ( 89.84%) | total_pruned =      13 | shape = (128,)
# layer2.1.conv2.weight | nonzeros =    4222 /  147456 (  2.86%) | total_pruned =  143234 | shape = (128, 128, 3, 3)
# layer2.1.bn2.weight  | nonzeros =       1 /     128 (  0.78%) | total_pruned =     127 | shape = (128,)
# layer2.1.bn2.bias    | nonzeros =     124 /     128 ( 96.88%) | total_pruned =       4 | shape = (128,)
# layer3.0.conv1.weight | nonzeros =    8406 /  294912 (  2.85%) | total_pruned =  286506 | shape = (256, 128, 3, 3)
# layer3.0.bn1.weight  | nonzeros =       4 /     256 (  1.56%) | total_pruned =     252 | shape = (256,)
# layer3.0.bn1.bias    | nonzeros =     230 /     256 ( 89.84%) | total_pruned =      26 | shape = (256,)
# layer3.0.conv2.weight | nonzeros =   16763 /  589824 (  2.84%) | total_pruned =  573061 | shape = (256, 256, 3, 3)
# layer3.0.bn2.weight  | nonzeros =       4 /     256 (  1.56%) | total_pruned =     252 | shape = (256,)
# layer3.0.bn2.bias    | nonzeros =     240 /     256 ( 93.75%) | total_pruned =      16 | shape = (256,)
# layer3.0.downsample.0.weight | nonzeros =     970 /   32768 (  2.96%) | total_pruned =   31798 | shape = (256, 128, 1, 1)
# layer3.0.downsample.1.weight | nonzeros =       4 /     256 (  1.56%) | total_pruned =     252 | shape = (256,)
# layer3.0.downsample.1.bias | nonzeros =     240 /     256 ( 93.75%) | total_pruned =      16 | shape = (256,)
# layer3.1.conv1.weight | nonzeros =   16755 /  589824 (  2.84%) | total_pruned =  573069 | shape = (256, 256, 3, 3)
# layer3.1.bn1.weight  | nonzeros =       4 /     256 (  1.56%) | total_pruned =     252 | shape = (256,)
# layer3.1.bn1.bias    | nonzeros =     231 /     256 ( 90.23%) | total_pruned =      25 | shape = (256,)
# layer3.1.conv2.weight | nonzeros =   16933 /  589824 (  2.87%) | total_pruned =  572891 | shape = (256, 256, 3, 3)
# layer3.1.bn2.weight  | nonzeros =       4 /     256 (  1.56%) | total_pruned =     252 | shape = (256,)
# layer3.1.bn2.bias    | nonzeros =     252 /     256 ( 98.44%) | total_pruned =       4 | shape = (256,)
# layer4.0.conv1.weight | nonzeros =   33622 / 1179648 (  2.85%) | total_pruned = 1146026 | shape = (512, 256, 3, 3)
# layer4.0.bn1.weight  | nonzeros =      10 /     512 (  1.95%) | total_pruned =     502 | shape = (512,)
# layer4.0.bn1.bias    | nonzeros =     461 /     512 ( 90.04%) | total_pruned =      51 | shape = (512,)
# layer4.0.conv2.weight | nonzeros =   66994 / 2359296 (  2.84%) | total_pruned = 2292302 | shape = (512, 512, 3, 3)
# layer4.0.bn2.weight  | nonzeros =      10 /     512 (  1.95%) | total_pruned =     502 | shape = (512,)
# layer4.0.bn2.bias    | nonzeros =     473 /     512 ( 92.38%) | total_pruned =      39 | shape = (512,)
# layer4.0.downsample.0.weight | nonzeros =    3817 /  131072 (  2.91%) | total_pruned =  127255 | shape = (512, 256, 1, 1)
# layer4.0.downsample.1.weight | nonzeros =      10 /     512 (  1.95%) | total_pruned =     502 | shape = (512,)
# layer4.0.downsample.1.bias | nonzeros =     473 /     512 ( 92.38%) | total_pruned =      39 | shape = (512,)
# layer4.1.conv1.weight | nonzeros =   66871 / 2359296 (  2.83%) | total_pruned = 2292425 | shape = (512, 512, 3, 3)
# layer4.1.bn1.weight  | nonzeros =      10 /     512 (  1.95%) | total_pruned =     502 | shape = (512,)
# layer4.1.bn1.bias    | nonzeros =     462 /     512 ( 90.23%) | total_pruned =      50 | shape = (512,)
# layer4.1.conv2.weight | nonzeros =   66848 / 2359296 (  2.83%) | total_pruned = 2292448 | shape = (512, 512, 3, 3)
# layer4.1.bn2.weight  | nonzeros =      10 /     512 (  1.95%) | total_pruned =     502 | shape = (512,)
# layer4.1.bn2.bias    | nonzeros =     481 /     512 ( 93.95%) | total_pruned =      31 | shape = (512,)
# fc.weight            | nonzeros =     141 /    5120 (  2.75%) | total_pruned =    4979 | shape = (10, 512)
# fc.bias              | nonzeros =      10 /      10 (100.00%) | total_pruned =       0 | shape = (10,)
# alive: 321985, pruned : 10850825, total: 11172810, Compression rate :      34.70x  ( 97.12% pruned)
# Train Epoch: 29/30 Loss: 1.400155 Accuracy: 50.81% Best Accuracy: 50.81%: 100%|████████| 30/30 [34:01<00:00, 68.04s/it]
